# %%
# Enable outputting results interactively. 
# All the results from code in a given cell will be displayed instead of only the last one.

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import plotly.plotly as py
import plotly.graph_objs as go
import plotly

import cufflinks
cufflinks.go_offline(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
import pandas as pd
import pickle
import numpy as np
import scipy.stats as stats
import sqlite3
import math
import datetime
import matplotlib.dates as mdates

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

# %%
reviews =  pickle.load( open( "../all_SF_reviews.p", "rb" ) )

loc =  pickle.load( open( "listings_loc.p", "rb" ) )

# %%
reviews.info()

conn = sqlite3.connect("airbnb.db")

# reviews.to_sql('reviews_db', conn, if_exists='replace')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 662849 entries, 0 to 10637373
# Data columns (total 6 columns):
# listing_id       662849 non-null int64
# id               662849 non-null int64
# date             662849 non-null object
# reviewer_id      662849 non-null int64
# reviewer_name    662848 non-null object
# comments         662259 non-null object
# dtypes: int64(3), object(3)
# memory usage: 35.4+ MB

# %%
reviews = reviews.merge(loc, how = 'left', on = 'listing_id')
reviews.groupby('std_nb').size().reset_index(name='counts').sort_values(by='counts', ascending=False)
# Out:
#                    std_nb  counts
# 16                Mission   77197
# 36       Western Addition   51920
# 2     Castro/Upper Market   43298
# 31        South of Market   36423
# 1          Bernal Heights   36258
# 23           Outer Sunset   33698
# 11         Haight Ashbury   31220
# 18             Noe Valley   29470
# 6   Downtown/Civic Center   27567
# 26           Potrero Hill   23688
# 12         Inner Richmond   21692
# 22         Outer Richmond   20030
# 17               Nob Hill   17140
# 15                 Marina   16920
# 21          Outer Mission   16333
# 13           Inner Sunset   14681
# 0                 Bayview   14468
# 19            North Beach   14423
# 7               Excelsior   13474
# 20             Ocean View   12900
# 29           Russian Hill   12462
# 25               Parkside   12375
# 24        Pacific Heights   12194
# 35     West of Twin Peaks   11511
# 8      Financial District   10132
# 34      Visitacion Valley    7359
# 33             Twin Peaks    6782
# 9               Glen Park    5880
# 4          Crocker Amazon    5729
# 14              Lakeshore    4150
# 3               Chinatown    3028
# 28       Presidio Heights    2923
# 5         Diamond Heights    2271
# 30               Seacliff    2091
# 10       Golden Gate Park    1226
# 32    Treasure Island/YBI     389
# 27               Presidio     292

# %%
reviews = reviews.set_index(pd.DatetimeIndex(reviews['date']))
reviews.head()
# Out:
#             listing_id     id        date  reviewer_id reviewer_name  \
# date
# 2009-07-23         958   5977  2009-07-23        15695      Edmund C
# 2009-08-03         958   6660  2009-08-03        26145         Simon
# 2009-09-27         958  11519  2009-09-27        25839         Denis
# 2009-11-05         958  16282  2009-11-05        33750          Anna
# 2010-02-13         958  26008  2010-02-13        15416       Venetia
#
#                                                      comments  \
# date
# 2009-07-23  Our experience was, without a doubt, a five st...
# 2009-08-03  Returning to San Francisco is a rejuvenating t...
# 2009-09-27  We were very pleased with the accommodations a...
# 2009-11-05  We highly recommend this accomodation and agre...
# 2010-02-13  Holly's place was great. It was exactly what I...
#
#                       std_nb
# date
# 2009-07-23  Western Addition
# 2009-08-03  Western Addition
# 2009-09-27  Western Addition
# 2009-11-05  Western Addition
# 2010-02-13  Western Addition

# %%
reviews.groupby('reviewer_id').size().reset_index(name='counts').sort_values(by='counts', ascending=False)
# Out:
#         reviewer_id  counts
# 50537       2895282      87
# 65497       3973648      57
# 240318     24713363      54
# 135113     10172884      53
# 350463     49656450      45
# 146928     11494959      44
# 165544     13749295      43
# 265744     28983728      42
# 92649       6090715      41
# 89348       5834919      38
# 218563     21186995      37
# 11204        507125      37
# 43981       2442976      37
# 23536       1220928      37
# 346876     48486550      36
# 66605       4060801      35
# 352374     50309421      34
# 64368       3883912      33
# 61567       3671922      33
# 362651     53844339      32
# 26194       1378587      32
# 96265       6369119      32
# 137439     10441917      32
# 313902     39224177      32
# 338791     45970431      31
# 210083     19994538      31
# 238469     24415477      31
# 74779       4706617      31
# 132389      9857476      30
# 53805       3127184      29
# ...             ...     ...
# 200062     18393063       1
# 200094     18399614       1
# 200080     18397267       1
# 200093     18399580       1
# 200091     18399490       1
# 200090     18399204       1
# 200089     18398957       1
# 200088     18398615       1
# 200087     18398435       1
# 200086     18398394       1
# 200085     18398390       1
# 200084     18398283       1
# 200083     18398192       1
# 200082     18398146       1
# 200081     18397324       1
# 200079     18397222       1
# 200064     18393530       1
# 200078     18396480       1
# 200077     18396218       1
# 200075     18396049       1
# 200074     18396040       1
# 200073     18396010       1
# 200072     18396009       1
# 200071     18395582       1
# 200070     18395221       1
# 200069     18394803       1
# 200068     18394553       1
# 200066     18393851       1
# 200065     18393781       1
# 541711    265081387       1
#
# [541712 rows x 2 columns]

# %%
reviews.groupby(['reviewer_id','listing_id']).size().reset_index(name='counts').sort_values(by='counts', ascending= False)
# Out:
#         reviewer_id  listing_id  counts
# 67702       2895282      472901      57
# 424663     49656450      256148      32
# 407787     45106320     8144647      27
# 426816     50309421    15068542      26
# 411357     45970431     5863674      25
# 447118     56736852     8352275      19
# 397579     42677539     6629798      15
# 422621     49054545     4650391      15
# 4109         136374       23611      14
# 164364      9386506     7921739      14
# 436139     53185668     5325355      13
# 269120     20738125    16441272      12
# 290684     23546330      752762      11
# 241574     17221187     5325355      11
# 236720     16680610     5049541      11
# 346253     31939285     4387067      10
# 11583        367756      918341      10
# 557629    118193671     1815551      10
# 269830     20822091      276072       9
# 536180    102230900    13590133       9
# 98849       4706617    10000073       9
# 362436     34947148     8775500       9
# 489988     73417009    14180032       9
# 35653       1357040       18904       9
# 134253      6977824     4875549       9
# 291944     23746366     5863674       9
# 145950      7876336     7055126       8
# 346255     31939285     5013816       8
# 442719     55268444     2298930       8
# 66203       2812854    13531532       8
# ...             ...         ...     ...
# 216210     14415644      708731       1
# 216211     14415708      786492       1
# 216212     14415708     9435665       1
# 216213     14415801     1918589       1
# 216214     14415815      406930       1
# 216215     14416069      580106       1
# 216216     14416069      760539       1
# 216217     14416069      905399       1
# 216218     14416069     8255582       1
# 216219     14416069     8650354       1
# 216220     14416219       60101       1
# 216205     14415516     4594699       1
# 216204     14415127    30175141       1
# 216203     14414888     2957148       1
# 216194     14414080      288213       1
# 216188     14413179     1197716       1
# 216189     14413251     3290739       1
# 216190     14413429      212125       1
# 41  33775      472901  169231920  2017-07-11      2895282         Emily
# 42  33778      472901  178100313  2017-08-04      2895282         Emily
# 43  33779      472901  180972071  2017-08-11      2895282         Emily
# 44  33781      472901  186482912  2017-08-24      2895282         Emily
# 45  33782      472901  193768908  2017-09-14      2895282         Emily
# 46  33784      472901  198245903  2017-09-28      2895282         Emily
# 47  33786      472901  202995684  2017-10-13      2895282         Emily
# 48  33787      472901  205029315  2017-10-20      2895282         Emily
# 49  33789      472901  208716540  2017-11-02      2895282         Emily
# 50  33791      472901  213556679  2017-11-21      2895282         Emily
# 51  33792      472901  215799517  2017-12-01      2895282         Emily
# 52  33794      472901  220278005  2017-12-21      2895282         Emily
# 53  33795      472901  221523624  2017-12-26      2895282         Emily
# 54  33796      472901  225497045  2018-01-06      2895282         Emily
# 55  33799      472901  248568102  2018-03-31      2895282         Emily
# 56  33801      472901  450226747  2019-05-08      2895282         Emily
#
#                                              comments
# 0   Jin was super quick with email responses, grea...
# 1   3rd time staying w. Jin - continue to be great...
# 2   Great stay per usual (wonderful communications...
# 3   I've stayed w. Jin many times and continues to...
# 4   Stayed w. Jin many times - see below. Great ex...
# 5   Stayed w. Jin many times - see below. Continue...
# 6   Thanks Jin for another great stay. Have a happ...
# 7   Stayed w. Jin many times. See below for more. ...
# 8   Continues to be great experience. See below fo...
# 9   Stayed w. Jin many times. See below for full f...
# 10     Stayed many time - great. See below. Thx Jin.
# 11                    Thanks Jin. Another nice stay!
# 12                           Thanks Jin - nice stay!
# 13  Stayed with Jin many times - great again. See ...
# 14                     Great stay again. Thanks Jin!
# 15                    Great stay again - thanks Jin!
# 16  Many stays with Jin. Continues to be very help...
# 17  Many stays with Jin (see below). Great as alwa...
# 18                       Terrific stay - thanks Jin.
# 19  Jin is always so easy & nice to communicate wi...
# 20              Thanks Jin for great stay per usual.
# 21                        Thanks Jin for great stay!
# 22       Stayed with Jin many times. Nice as always.
# 23                  Another great stay - thanks Jin!
# 24   Stayed many times. Great per usual. Thanks Jin.
# 25  Jin is a terrific host. Glad to stay with her ...
# 26  Thanks Jin for another great stay. See below f...
# 27                      Another great stay with Jin.
# 28                           Great stay. Thanks Jin.
# 29               Jin, thanks for a great stay again.
# 30                                       Thanks Jin!
# 31                      Another great stay. Thx Jin!
# 32                                  Many thanks Jin.
# 33                        Thank you Jin. Great stay.
# 34                                  Many thanks Jin.
# 35                        Thanks Jin for great stay.
# 36        Have a good weekend Jin! Thx for the stay.
# 37                                       Thanks Jin.
# 38                                        Thanks Jin
# 39                               Another great stay!
# 40                         Thanks Jin for nice stay.
# 41               Many stays with Jin. Thank you Jin.
# 42                     Stayed many times. Thanks Jin.
# 43                       Thanks Jin for a great stay.
# 44  Many times with Jin. Thanks for another great ...
# 45       Many stays. Close & convenient. Thanks Jin!
# 46         Many stays. See prior reviews. Thanks Jin.
# 47                 Thanks Jin for another great stay.
# 48                 Thanks Jin for another great stay.
# 49                                         Thanks Jin
# 50                                     Thank you Jin!
#  "It's a real hassle for me to go into SF, so knowing I have an incredibly comfortable place, in a great neighborhood with the best host around really takes the edge off the trip. Chris is awesome; a great conversationalist when you're feeling chatty and someone who knows when you're not. The place is clean, comfortable, convenient. If Chris doesn't have an open spot (and she's usually pretty booked up!) I'll wait till she does rather than trying anywhere else! I give it my highest recommendation!",
#  "This is my favorite place to stay at ever! It's comfortable, cozy and clean. The location is perfect for me to get into work in SF.\n\nThe only downside this visit was that Chris was traveling; I really missed the conversations we have!\n\nWonderful experience as always!",
#  "This is the second time I've stayed at Chris' and thankfully I'll get to stay there next week! Chris is the most welcoming host. She's charming, extremely knowledgeable about the area and the city and a fantastic conversationalist. She made my wife and I feel like  family.\r\n\r\nOur room was clean and comfortable and the location is ideal. There's a reason Chris is an Airbnb SuperHost!  Thanks so much.",
#  "This is the third time I've stayed at Chris' and if I had my d'ruthers this would be the only place I'd stay at! Chris is a great host, a witty and fascinating conversationalist. I love the location and the room is super comfortable.",
#  "This is the third time I've stayed at Chris'. It's my favorite Airbnb in SF. It's extremely comfortable and I just love hanging out and chatting with Chris. Great spot!",
#  'Unless I really really have to, I won’t stay anywhere else but Chris’ when I come into the City. It ticks all the boxes: convenient to transportation, restaurants, it’s clean and comfortable and Chris and Lisa are some of the most amazing people I’ve ever met. Best place ever!'}

# %%
reviews.groupby('listing_id').size().reset_index(name='counts').sort_values(by='counts', ascending=False)
# Out:
#        listing_id  counts
# 959        545685     741
# 12           8739     715
# 413        205842     674
# 3049      1920033     672
# 1022       585326     667
# 1293       748256     653
# 995        567239     652
# 1291       748222     643
# 2346      1393654     638
# 93          33577     634
# 519        256148     610
# 94          33578     598
# 1697       992676     557
# 284        114401     547
# 1779      1043282     544
# 1223       713877     535
# 1021       585225     529
# 5485      4439461     529
# 6515      5550248     522
# 5427      4387067     521
# 6131      5013816     518
# 3166      1995487     509
# 6901      6092596     506
# 9725      9051149     502
# 14           9225     494
# 422        208831     480
# 4300      3257886     479
# 6041      4902855     473
# 4062      2956406     471
# 4050      2944843     470
# ...           ...     ...
# 13133    13782508       1
# 13132    13782030       1
# 13130    13779778       1
# 13126    13772732       1
# 13120    13769730       1
# 13112    13764695       1
# 13109    13755049       1
# 13103    13751291       1
# 13102    13749669       1
# 13100    13749110       1
# 13204    13877547       1
# 13209    13882758       1
# 13328    14012294       1
# 13214    13885045       1
# 13327    14011904       1
# 13326    14011529       1
# 13318    13997869       1
# 13315    13996915       1
# 13314    13996790       1
# 13289    13961800       1
# 13287    13961327       1
# 13269    13937718       1
# 13263    13927372       1
# 13262    13927209       1
# 13247    13912834       1
# 13228    13898734       1
# 13222    13895004       1
# 13219    13888121       1
# 13217    13885627       1
# 21210    35094989       1
#
# [21211 rows x 2 columns]

# %%
reviews_tab = reviews.resample('W').size().reset_index(name='Counts') 
reviews_tab = reviews_tab.set_index(pd.DatetimeIndex(reviews_tab['date']))

reviews_tab_post2015 = reviews_tab['2015-05-01':]
reviews_tab_post2015.head()
# Out:
#                  date  Counts
# date
# 2015-05-03 2015-05-03    1676
# 2015-05-10 2015-05-10    1605
# 2015-05-17 2015-05-17    1702
# 2015-05-24 2015-05-24    2165
# 2015-05-31 2015-05-31    2021

# %%
xlinspace = pd.date_range('2015-05-01', periods= reviews_tab_post2015.shape[0], freq='W')

fig, ax = plt.subplots(1,figsize = (15,10))
fig.autofmt_xdate()
plt.plot(xlinspace,reviews_tab_post2015['Counts'])

# Dreamforce dates 2015 - 2018

plt.axvline(x= datetime.date(2015,9,18), color = 'red', linestyle='--')
plt.axvline(x= datetime.date(2016,10,7), color = 'red', linestyle='--')
plt.axvline(x= datetime.date(2017,11,9), color = 'red', linestyle='--')
plt.axvline(x= datetime.date(2018,9,28), color = 'red', linestyle='--')

# # Outside Lands Festival
# plt.axvline(x= datetime.date(2018,8,12), color = 'c', linestyle='--')
# plt.axvline(x= datetime.date(2017,8,13), color = 'c', linestyle='--')

# # GDC
# plt.axvline(x= datetime.date(2018,3,23), color = 'b', linestyle='--')

    
# Superbowl in 2016
plt.axvline(x= datetime.date(2016,2,7), color = 'black', linestyle='--')



ax.set_ylim(0,5000)
plt.xlabel("Date")
plt.ylabel("Number of Bookings ")
plt.title("Weekly Number of Bookings on Airbnb: May 2015 - June 2019")

xfmt = mdates.DateFormatter('%m-%d-%y')


plt.show();

# %%
import statsmodels.api as sm

reviews_tab = reviews.resample('W').size().reset_index(name='Counts') 
reviews_tab = reviews_tab.set_index(pd.DatetimeIndex(reviews_tab['date']))

reviews_tab_post2015 = reviews_tab['2015-05-01':]

decomposition = sm.tsa.seasonal_decompose(reviews_tab_post2015.dropna()['Counts'].values, model='additive', freq= 52)  
booking_decomp = reviews_tab_post2015.dropna().copy()
booking_decomp['trend'] = decomposition.trend
booking_decomp['seasonal'] = decomposition.seasonal
booking_decomp['resid'] = decomposition.resid

fig, axs = plt.subplots(4,1, figsize=(10,10), sharex=True)
columns = ['Counts','trend','seasonal','resid']

for i, ax in enumerate(axs):
    ax.set_title('Decompostion of Weekly Bookings on Airbnb: 2009 - 2019')
    ax.plot(booking_decomp.index, booking_decomp[columns[i]].values, lw=.5)
    ax.set_ylabel(columns[i].capitalize(), size=10)
# Out:
# Text(0.5, 1.0, 'Decompostion of Weekly Bookings on Airbnb: 2009 - 2019')
# Text(0, 0.5, 'Counts')
# Text(0.5, 1.0, 'Decompostion of Weekly Bookings on Airbnb: 2009 - 2019')
# Text(0, 0.5, 'Trend')
# Text(0.5, 1.0, 'Decompostion of Weekly Bookings on Airbnb: 2009 - 2019')
# Text(0, 0.5, 'Seasonal')
# Text(0.5, 1.0, 'Decompostion of Weekly Bookings on Airbnb: 2009 - 2019')
# Text(0, 0.5, 'Resid')

# %%
reviews_tab_D = reviews.resample('W').size().reset_index(name='Counts') 
reviews_tab_D = reviews_tab_D.set_index(pd.DatetimeIndex(reviews_tab_D['date']))


reviews_tab2018 = reviews_tab_D['2018-01-01': '2018-12-31']

xlinspace = pd.date_range('2018-01-01', periods= reviews_tab2018.shape[0], freq='W')

fig, ax = plt.subplots(1,figsize = (15,10))
fig.autofmt_xdate()
plt.plot(xlinspace,reviews_tab2018['Counts'])

# Dreamforce dates 2018

plt.axvline(x= datetime.date(2018,9,28), color = 'red', linestyle='--')

# Outside Lands Festival
plt.axvline(x= datetime.date(2018,8,12), color = 'c', linestyle='--')

# GDC
plt.axvline(x= datetime.date(2018,3,23), color = 'b', linestyle='--')


ax.set_ylim(0,5000)
plt.xlabel("Date")
plt.ylabel("Number of Bookings ")
plt.title("Weekly Number of Bookings on Airbnb: Jan 2018 - Dec 2018")

xfmt = mdates.DateFormatter('%m-%d-%y')


plt.show();

# %%
reviews['date'] = pd.to_datetime(reviews['date'])
reviews.dtypes
# Out:
# listing_id                int64
# id                        int64
# date             datetime64[ns]
# reviewer_id               int64
# reviewer_name            object
# comments                 object
# std_nb                   object
# dtype: object

# %%
reviews_sub = reviews['2015-05-01':]

# %%
reviews_sub.groupby('std_nb').size().reset_index(name='counts').sort_values(by='counts', ascending = False)
# Out:
#                    std_nb  counts
# 16                Mission   59025
# 36       Western Addition   39796
# 2     Castro/Upper Market   32215
# 23           Outer Sunset   30416
# 31        South of Market   29301
# 1          Bernal Heights   29128
# 18             Noe Valley   23900
# 6   Downtown/Civic Center   23557
# 11         Haight Ashbury   23137
# 12         Inner Richmond   18574
# 26           Potrero Hill   17711
# 22         Outer Richmond   17255
# 21          Outer Mission   13933
# 17               Nob Hill   13280
# 0                 Bayview   13035
# 15                 Marina   12870
# 7               Excelsior   12598
# 20             Ocean View   11989
# 13           Inner Sunset   11960
# 25               Parkside   11368
# 19            North Beach   11267
# 24        Pacific Heights   10266
# 35     West of Twin Peaks    9768
# 29           Russian Hill    9455
# 8      Financial District    7637
# 34      Visitacion Valley    6823
# 33             Twin Peaks    5576
# 4          Crocker Amazon    4837
# 9               Glen Park    4503
# 14              Lakeshore    3825
# 3               Chinatown    2388
# 28       Presidio Heights    2027
# 5         Diamond Heights    1861
# 30               Seacliff    1698
# 10       Golden Gate Park     766
# 32    Treasure Island/YBI     274
# 27               Presidio     229

# %%
grouper = reviews_sub.groupby([pd.Grouper(freq='1W'), 'std_nb'])
demand_loc = grouper.size().reset_index(name = 'counts')

demand_loc.head()
# Out:
#         date               std_nb  counts
# 0 2015-05-03              Bayview      12
# 1 2015-05-03       Bernal Heights      41
# 2 2015-05-03  Castro/Upper Market      71
# 3 2015-05-03            Chinatown       5
# 4 2015-05-03       Crocker Amazon       1

# %%
lst = ['Mission', 'South of Market', 'Financial District','Inner Sunset']

for_chart = demand_loc[demand_loc['std_nb'].isin(lst)]

fig, ax = plt.subplots(1,1,figsize = (15,10))

sns.lineplot(x= 'date', y='counts', hue = 'std_nb', data = for_chart)
# Dreamforce dates 2015 - 2018

plt.axvline(x= datetime.date(2015,9,18), color = 'red', linestyle='--')
plt.axvline(x= datetime.date(2016,10,7), color = 'red', linestyle='--')
plt.axvline(x= datetime.date(2017,11,9), color = 'red', linestyle='--')
plt.axvline(x= datetime.date(2018,9,28), color = 'red', linestyle='--')

# Superbowl in 2016
plt.axvline(x= datetime.date(2016,2,7), color = 'black', linestyle='--')

plt.title("Demand by Neighborhood")
plt.xlabel("Date")
plt.ylabel("Number of Reviews");
