# %%
# Enable outputting results interactively. 
# All the results from code in a given cell will be displayed instead of only the last one.

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import pandas as pd
import pickle
import numpy as np
import scipy.stats as stats
import sqlite3
import math
import datetime
import matplotlib.dates as mdates

from re import sub
from decimal import Decimal

import re
import calendar 

import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

# %%
from sklearn.preprocessing import LabelEncoder, OneHotEncoder

from sklearn.model_selection import train_test_split, ShuffleSplit
from sklearn.ensemble import (GradientBoostingRegressor, RandomForestRegressor)
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from collections import defaultdict

from sklearn.decomposition import PCA

# %%
listings_loc =  pickle.load( open( "../data/listings_loc.p", "rb" ) )

# %%
listings_loc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26502 entries, 0 to 26501
# Data columns (total 2 columns):
# listing_id    26502 non-null int64
# std_nb        26502 non-null object
# dtypes: int64(1), object(1)
# memory usage: 414.2+ KB

# %%
calendar_price =  pickle.load( open( "../data/calendar_pricing.p", "rb" ) ) 
calendar_price.shape
# Out:
# (20595249, 10)

# %%
# get standardized neighborhood name

calendar_price = calendar_price.merge(listings_loc, how='left', on = 'listing_id')
calendar_price.shape
# Out:
# (20595249, 11)

# %%
# limit to private rooms only

listings_short_avail =  pickle.load( open( "../data/listings_short_avail.p", "rb" ) )
listings_short_avail.room_type.value_counts()
private_room = listings_short_avail[listings_short_avail['room_type'] == "Private room"]
PR_listings = list(set(private_room['id']))
# Out:
# Entire home/apt    112806
# Private room        84450
# Shared room          6458
# Name: room_type, dtype: int64

# %%
calendar_price = calendar_price[calendar_price['listing_id'].isin(PR_listings)]

# %%
# exclude listings that could be either short-term or long-term rentals


with open('../data/dual_status_listings.pkl', 'rb') as f:
      del_listings = pickle.load(f)
len(del_listings)
# Out:
# 2625

# %%
# limit to short-term only

calendar_price = calendar_price[~calendar_price['listing_id'].isin(del_listings)]
calendar_price.shape
# Out:
# (8579569, 11)

# %%
calendar_price.head(2)
# Out:
#    listing_id       date available  price adjusted_price  minimum_nights  \
# 0        9225 2019-06-04         t  105.0        $105.00             1.0
# 1        9225 2019-06-09         t  105.0        $105.00             1.0
#
#    maximum_nights file_scraped_dt  lead_time    month        std_nb
# 0           365.0      2019-06-02          2  2019-06  Potrero Hill
# 1           365.0      2019-06-02          7  2019-06  Potrero Hill

# %%
calendar_price['listing_id'].nunique()
# Out:
# 3647

# %%
calendar_price.dtypes
# Out:
# listing_id                  int64
# date               datetime64[ns]
# available                  object
# price                     float64
# adjusted_price             object
# minimum_nights            float64
# maximum_nights            float64
# file_scraped_dt    datetime64[ns]
# lead_time                   int64
# month                      object
# std_nb                     object
# dtype: object

# %%
calendar_price = calendar_price.set_index(pd.DatetimeIndex(calendar_price['date']))

# %%
calendar_price['year'] =calendar_price.index.strftime('%Y').astype('int64')

calendar_price['month_yr'] =calendar_price.index.strftime('%m').astype('int64')

calendar_price['month_abbr'] = calendar_price['month_yr'].apply(lambda x: calendar.month_name[x])

calendar_price.drop('month_yr', axis = 1)
# Out:
#             listing_id       date available  price adjusted_price  \
# date
# 2019-06-04        9225 2019-06-04         t  105.0        $105.00
# 2019-06-09        9225 2019-06-09         t  105.0        $105.00
# 2019-06-13        9225 2019-06-13         t  115.0        $115.00
# 2019-06-19        9225 2019-06-19         t  150.0        $150.00
# 2019-06-20        9225 2019-06-20         t  150.0        $150.00
# 2019-06-21        9225 2019-06-21         t  150.0        $150.00
# 2019-06-26        9225 2019-06-26         t  115.0        $115.00
# 2019-06-28        9225 2019-06-28         t  115.0        $115.00
# 2019-07-01        9225 2019-07-01         t  125.0        $125.00
# 2019-07-02        9225 2019-07-02         t  125.0        $125.00
# 2019-07-03        9225 2019-07-03         t  145.0        $145.00
# 2019-07-04        9225 2019-07-04         t  145.0        $145.00
# 2019-07-05        9225 2019-07-05         t  145.0        $145.00
# 2019-07-06        9225 2019-07-06         t  145.0        $145.00
# 2019-07-07        9225 2019-07-07         t  140.0        $140.00
# 2019-07-08        9225 2019-07-08         t  140.0        $140.00
# 2019-07-09        9225 2019-07-09         t  140.0        $140.00
# 2019-07-12        9225 2019-07-12         t  140.0        $140.00
# 2019-07-15        9225 2019-07-15         t  125.0        $125.00
# 2019-07-16        9225 2019-07-16         t  125.0        $125.00
# 2019-07-17        9225 2019-07-17         t  125.0        $125.00
# 2019-07-18        9225 2019-07-18         t  125.0        $125.00
# 2019-07-19        9225 2019-07-19         t  135.0        $135.00
# 2019-07-20        9225 2019-07-20         t  135.0        $135.00
# 2019-07-21        9225 2019-07-21         t  135.0        $135.00
# 2019-07-25        9225 2019-07-25         t  115.0        $115.00
# 2019-07-28        9225 2019-07-28         t  130.0        $130.00
# 2019-07-29        9225 2019-07-29         t  130.0        $130.00
# 2019-07-30        9225 2019-07-30         t  130.0        $130.00
# 2019-07-31        9225 2019-07-31         t  130.0        $130.00
# ...                ...        ...       ...    ...            ...
# 2016-04-04     1596696 2016-04-04         t  130.0            NaN
# 2016-04-05     1596696 2016-04-05         t  130.0            NaN
# 2016-04-06     1596696 2016-04-06         t  130.0            NaN
# 2016-04-07     1596696 2016-04-07         t  130.0            NaN
# 2016-04-08     1596696 2016-04-08         t  130.0            NaN
# 2016-04-09     1596696 2016-04-09         t  130.0            NaN
# 2016-04-10     1596696 2016-04-10         t  130.0            NaN
# 2016-04-11     1596696 2016-04-11         t  130.0            NaN
# 2016-04-12     1596696 2016-04-12         t  130.0            NaN
# 2016-04-13     1596696 2016-04-13         t  130.0            NaN
# 2016-04-14     1596696 2016-04-14         t  130.0            NaN
# 2016-04-15     1596696 2016-04-15         t  130.0            NaN
# 2016-04-16     1596696 2016-04-16         t  130.0            NaN
# 2016-04-17     1596696 2016-04-17         t  130.0            NaN
# 2016-04-18     1596696 2016-04-18         t  130.0            NaN
# 2016-04-19     1596696 2016-04-19         t  130.0            NaN
# 2019-07-31  2019-06      Potrero Hill  2019       July
# ...             ...               ...   ...        ...
# 2016-04-04  2015-05  Western Addition  2016      April
# 2016-04-05  2015-05  Western Addition  2016      April
# 2016-04-06  2015-05  Western Addition  2016      April
# 2016-04-07  2015-05  Western Addition  2016      April
# 2016-04-08  2015-05  Western Addition  2016      April
# 2016-04-09  2015-05  Western Addition  2016      April
# 2016-04-10  2015-05  Western Addition  2016      April
# 2016-04-11  2015-05  Western Addition  2016      April
# 2016-04-12  2015-05  Western Addition  2016      April
# 2016-04-13  2015-05  Western Addition  2016      April
# 2016-04-14  2015-05  Western Addition  2016      April
# 2016-04-15  2015-05  Western Addition  2016      April
# 2016-04-16  2015-05  Western Addition  2016      April
# 2016-04-17  2015-05  Western Addition  2016      April
# 2016-04-18  2015-05  Western Addition  2016      April
# 2016-04-19  2015-05  Western Addition  2016      April
# 2016-04-20  2015-05  Western Addition  2016      April
# 2016-04-21  2015-05  Western Addition  2016      April
# 2016-04-22  2015-05  Western Addition  2016      April
# 2016-04-23  2015-05  Western Addition  2016      April
# 2016-04-24  2015-05  Western Addition  2016      April
# 2016-04-25  2015-05  Western Addition  2016      April
# 2016-04-26  2015-05  Western Addition  2016      April
# 2016-04-27  2015-05  Western Addition  2016      April
# 2016-04-28  2015-05  Western Addition  2016      April
# 2016-04-29  2015-05  Western Addition  2016      April
# 2016-04-30  2015-05  Western Addition  2016      April
# 2016-05-01  2015-05  Western Addition  2016        May
# 2016-05-02  2015-05  Western Addition  2016        May
# 2016-05-03  2015-05  Western Addition  2016        May
#
# [8579569 rows x 13 columns]

# %%
calendar_price['scraped_month'] = calendar_price['file_scraped_dt'].dt.month
calendar_price['scraped_month_abbr'] = calendar_price['scraped_month'].apply(lambda x: calendar.month_name[x])
calendar_price.head()

calendar_price = calendar_price.drop('scraped_month', axis = 1)
# Out:
#             listing_id       date available  price adjusted_price  \
# date
# 2019-06-04        9225 2019-06-04         t  105.0        $105.00
# 2019-06-09        9225 2019-06-09         t  105.0        $105.00
# 2019-06-13        9225 2019-06-13         t  115.0        $115.00
# 2019-06-19        9225 2019-06-19         t  150.0        $150.00
# 2019-06-20        9225 2019-06-20         t  150.0        $150.00
#
#             minimum_nights  maximum_nights file_scraped_dt  lead_time  \
# date
# 2019-06-04             1.0           365.0      2019-06-02          2
# 2019-06-09             1.0           365.0      2019-06-02          7
# 2019-06-13             1.0           365.0      2019-06-02         11
# 2019-06-19             1.0           365.0      2019-06-02         17
# 2019-06-20             1.0           365.0      2019-06-02         18
#
#               month        std_nb  year  month_yr month_abbr  scraped_month  \
# date
# 2019-06-04  2019-06  Potrero Hill  2019         6       June              6
# 2019-06-09  2019-06  Potrero Hill  2019         6       June              6
# 2019-06-13  2019-06  Potrero Hill  2019         6       June              6
# 2019-06-19  2019-06  Potrero Hill  2019         6       June              6
# 2019-06-20  2019-06  Potrero Hill  2019         6       June              6
#
#            scraped_month_abbr
# date
# 2019-06-04               June
# 2019-06-09               June
# 2019-06-13               June
# 2019-06-19               June
# 2019-06-20               June

# %%
calendar_price['day_of_week'] = calendar_price['date'].dt.day_name()
calendar_price.day_of_week.value_counts()
# Out:
# Tuesday      1242328
# Monday       1239893
# Wednesday    1237578
# Sunday       1227611
# Thursday     1224603
# Friday       1205957
# Saturday     1201599
# Name: day_of_week, dtype: int64

# %%
calendar_price['price'].min()
# Out:
# 10.0

# %%
calendar_price['price'].max()
# Out:
# 9589.0

# %%
PR_p = np.asarray(calendar_price['price'])

PR_1pct = np.percentile(PR_p, 1)
PR_99pct = np.percentile(PR_p, 99)

PR_1pct, PR_99pct
# Out:
# (50.0, 445.0)

# %%
private_room = calendar_price[calendar_price['price'] <= PR_99pct ]
private_room = calendar_price[calendar_price['price'] >= PR_1pct ]

# %%
y = np.log(private_room.pop('price'))
y.shape
# Out:
# (8504005,)

# %%
private_room.head()

X = private_room[['lead_time', 'std_nb', 'month_abbr','day_of_week']]
# Out:
#             listing_id       date available adjusted_price  minimum_nights  \
# date
# 2019-06-04        9225 2019-06-04         t        $105.00             1.0
# 2019-06-09        9225 2019-06-09         t        $105.00             1.0
# 2019-06-13        9225 2019-06-13         t        $115.00             1.0
# 2019-06-19        9225 2019-06-19         t        $150.00             1.0
# 2019-06-20        9225 2019-06-20         t        $150.00             1.0
#
#             maximum_nights file_scraped_dt  lead_time    month        std_nb  \
# date
# 2019-06-04           365.0      2019-06-02          2  2019-06  Potrero Hill
# 2019-06-09           365.0      2019-06-02          7  2019-06  Potrero Hill
# 2019-06-13           365.0      2019-06-02         11  2019-06  Potrero Hill
# 2019-06-19           365.0      2019-06-02         17  2019-06  Potrero Hill
# 2019-06-20           365.0      2019-06-02         18  2019-06  Potrero Hill
#
#             year  month_yr month_abbr scraped_month_abbr day_of_week
# date
# 2019-06-04  2019         6       June               June     Tuesday
# 2019-06-09  2019         6       June               June      Sunday
# 2019-06-13  2019         6       June               June    Thursday
# 2019-06-19  2019         6       June               June   Wednesday
# 2019-06-20  2019         6       June               June    Thursday

# %%
def get_dummy(df):
    dummy_col=df.select_dtypes('object').columns
    new_df=pd.get_dummies(df, columns=dummy_col, dummy_na=True,prefix=dummy_col)
    return new_df

# %%
def tt_split(X, y, test_size=.3):
    X_train, X_test, y_train, y_test=train_test_split(X,y, test_size=test_size)
    return X_train, X_test, y_train, y_test

# %%
X=get_dummy(X)

X_train, X_test, y_train, y_test = tt_split(X,y)

# %%
rfr=RandomForestRegressor(max_depth=5, n_estimators=10)
rfr.fit(X_train.values, y_train)

# %%
print("R2 of test: {:2.2f}".format(rfr.score(X_test, y_test)))

# %%
# Out:
# (8504005, 73)
